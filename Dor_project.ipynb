# %%
import pandas as pd
df = pd.read_csv('dor.csv')
df
# Out:
#            State_UT     year Primary_Boys Primary_Girls Primary_Total  \
# 0     A & N Islands  2012-13         0.83          0.51          0.68
# 1     A & N Islands  2013-14         1.35          1.06          1.21
# 2     A & N Islands  2014-15         0.47          0.55          0.51
# 3    Andhra Pradesh  2012-13          3.3          3.05          3.18
# 4    Andhra Pradesh  2013-14         4.31          4.39          4.35
# ..              ...      ...          ...           ...           ...
# 105     West Bengal  2013-14         3.44          2.37          2.91
# 106     West Bengal  2014-15         2.13          0.79          1.47
# 107       All India  2012-13         4.68          4.66          4.67
# 108       All India  2013-14         4.53          4.14          4.34
# 109       All India  2014-15         4.36          3.88          4.13
#
#     Upper Primary_Boys Upper Primary_Girls Upper Primary_Total  \
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                  State_UT     year Primary_Boys Primary_Girls Primary_Total Upper Primary_Boys Upper Primary_Girls Upper Primary_Total Secondary _Boys Secondary _Girls Secondary _Total HrSecondary_Boys HrSecondary_Girls HrSecondary_Total
# 0           A & N Islands  2012-13         0.83          0.51          0.68     Uppe_r_Primary                1.09                1.23            5.57             5.55             5.56            17.66             10.15             14.14
# 1           A & N Islands  2013-14         1.35          1.06          1.21                 NR                1.54                0.51            8.36             5.98              7.2            18.94              12.2             15.87
# 2           A & N Islands  2014-15         0.47          0.55          0.51               1.44                1.95                1.69           11.47             8.16             9.87            21.05             12.21             16.93
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   State_UT             110 non-null    object
#  1   year                 110 non-null    object
#  2   Primary_Boys         110 non-null    object
#  3   Primary_Girls        110 non-null    object
#  4   Primary_Total        110 non-null    object
#  5   Upper Primary_Boys   110 non-null    object
#  6   Upper Primary_Girls  110 non-null    object
#  7   Upper Primary_Total  110 non-null    object
#  8   Secondary _Boys      110 non-null    object
#  9   Secondary _Girls     110 non-null    object
#  10  Secondary _Total     110 non-null    object
#  11  HrSecondary_Boys     110 non-null    object
#  12  HrSecondary_Girls    110 non-null    object
#  13  HrSecondary_Total    110 non-null    object
# dtypes: object(14)
# memory usage: 12.2+ KB

# %%
df['year'] = pd.to_numeric(df['year'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\lib.pyx:2364, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "2012-13"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 df['year'] = pd.to_numeric(df['year'])
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\tools\numeric.py:185, in to_numeric(arg, errors, downcast)
#     183 coerce_numeric = errors not in ("ignore", "raise")
#     184 try:
# --> 185     values, _ = lib.maybe_convert_numeric(
#     186         values, set(), coerce_numeric=coerce_numeric
#     187     )
#     188 except (ValueError, TypeError):
#     189     if errors == "raise":
#
# ...

# %%
pd.set_option('display.max_rows' ,500)
pd.set_option('display.max_columns' ,500)
pd.set_option('display.width',1000)

# %% [markdown]
# ## Oosc rates of all the states in the year range of 2012-15

# %%
import matplotlib.pyplot as plt
plt.plot(df['year'],df['State_UT'],label='dor')
plt.legend()

# %% [markdown]
# ## Oosc rate of primary boys over the states

# %%
plt.plot(df['State_UT'],df['Primary_Boys'],label ='pri_boys')
plt.grid(True)
plt.legend()

# %% [markdown]
# ## Oosc rates of primary boys over the years

# %%
plt.plot(df['year'],df['Primary_Boys'],label ='pri_boys')
plt.grid(True)
plt.legend()

# %% [markdown]
# ## Histogram
# ## Oosc rates of primary students over the states in the year range of 2012-15

# %%
fig,axes= plt.subplots(2,2)
axes[0,0].hist(df['State_UT'])
axes[0,1].plot(df['year'],df['Primary_Boys'])
axes[1,0].plot(df['year'],df['Primary_Girls'])
axes[1,1].plot(df['year'],df['Primary_Total'])

# %% [markdown]
# ## Out-of-school students identification over the years 2012-15

# %%
plt.plot(df['year'],df['Primary_Total'],label ='Primary_Total')
plt.plot(df['year'],df['Upper Primary_Total'],label ='Upper Primary_Total')
plt.plot(df['year'],df['Secondary _Total'],label ='Secondary _Total')
plt.plot(df['year'],df['HrSecondary_Total'],label ='HrSecondary_Total')
plt.grid(True)
plt.legend()

# %%
plt.plot(df['year'],df['Primary_Total'],'r-')
plt.plot(df['year'],df['Upper Primary_Total'],'bs')
plt.plot(df['year'],df['Secondary _Total'], 'g^')
plt.plot(df['year'],df['HrSecondary_Total'],'p-')

# %% [markdown]
# ## Scatterplot

# %%
plt.scatter(df['year'],df['Primary_Total'])
plt.scatter(df['year'],df['Upper Primary_Total'])
plt.scatter(df['year'],df['Secondary _Total'],)
plt.scatter(df['year'],df['HrSecondary_Total'])

# %%
import seaborn as sns
sns.set()
sns.scatterplot(df['Primary_Total'])
# Out:
# <AxesSubplot: ylabel='Primary_Total'>

# %%
sns.relplot(x= 'year', y='Primary_Total',hue='Upper Primary_Total',size ='Secondary _Total',cmap='HrSecondary_Total',data=df)
# Out:
# C:\Users\Anusha\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\relational.py:567: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   points = ax.scatter(x=x, y=y, **kws)

# %% [markdown]
# ## Heatmap

# %%
import numpy as np
df= np.random.rand(10,10)
plt.pcolormesh(df, cmap = 'rainbow')
plt.title('HeatMap')
# Out:
# Text(0.5, 1.0, 'HeatMap')

# %% [markdown]
# ## Jointplot

# %%
sns.jointplot(x='year',y='Primary_Total',data =df)

# %%
sns.jointplot(x='HrSecondary_Total',y='Primary_Total',data =df)

# %%
df.State_UT.describe()
# Out:
# count               110
# unique               40
# top       A & N Islands
# freq                  3
# Name: State_UT, dtype: object

# %%
len (df)
# Out:
# 110
