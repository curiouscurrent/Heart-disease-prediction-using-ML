# %%
import pandas as pd
df = pd.read_csv('hackathon1.csv')
df.head()
# Out:
#    ac_year  statcd           statname  area_sqkm  tot_population  \
# 0  2015-16       1  Jammu And Kashmir     222236        12548.93
# 1  2015-16       2   Himachal Pradesh      55673         6856.51
# 2  2015-16       3             Punjab      50362        27704.24
# 3  2015-16       4         Chandigarh        114         1054.69
# 4  2015-16       5        Uttarakhand      53483        10116.75
#
#    urban_population  grwoth_rate  sexratio  sc_population  st_population  ...  \
# 0             20.05        23.71       883            7.4           11.9  ...
# 1              8.69        12.81       974           25.2            5.7  ...
# 2             29.82        13.73       893           31.9            0.0  ...
# 3             76.66        17.10       818           18.9            0.0  ...
# 4             21.54        19.17       963           18.8            2.9  ...
#
#    sch_r_5  sch_r_6  sch_r_7  sch_u_1  sch_u_2  sch_u_3  sch_u_4  sch_u_5  \
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     ac_year  statcd                        statname  area_sqkm  \
# 0   2015-16       1               Jammu And Kashmir     222236
# 1   2015-16       2                Himachal Pradesh      55673
# 2   2015-16       3                          Punjab      50362
# 3   2015-16       4                      Chandigarh        114
# 4   2015-16       5                     Uttarakhand      53483
# 5   2015-16       6                         Haryana      44212
# 6   2015-16       7  Delhi                                1483
# 7   2015-16       8  Rajasthan                          342239
# 8   2015-16       9                   Uttar Pradesh     240928
# 9   2015-16      10                           Bihar      94163
# 10  2015-16      11                          Sikkim       7096
# 11  2015-16      12               Arunachal Pradesh      83743
# 12  2015-16      13                        Nagaland      16579
# ...

# %%
df.head()
# Out:
#    ac_year  statcd           statname  area_sqkm  tot_population  urban_population  grwoth_rate  sexratio  sc_population  st_population  literacy_rate  male_literacy_rate  female_literacy_rate  distcd  blkcd  villages  clusters  schools  sch_1  sch_2  sch_3  sch_4  sch_5  sch_6  sch_7  sch_r_1  sch_r_2  sch_r_3  sch_r_4  sch_r_5  sch_r_6  sch_r_7  sch_u_1  sch_u_2  sch_u_3  sch_u_4  sch_u_5  sch_u_6  sch_u_7
# 0  2015-16       1  Jammu And Kashmir     222236        12548.93             20.05        23.71       883            7.4           11.9          68.74               78.26                 58.01      22    201      7263      1628     4202    486     95   2693    414     34    478      2      264       90     2012      376       30      346        0      222        5      681       38        4      132        2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 39 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ac_year               35 non-null     object
#  1   statcd                35 non-null     int64
#  2   statname              35 non-null     object
#  3   area_sqkm             35 non-null     int64
#  4   tot_population        35 non-null     float64
#  5   urban_population      35 non-null     float64
#  6   grwoth_rate           35 non-null     float64
#  7   sexratio              35 non-null     int64
#  8   sc_population         35 non-null     float64
#  9   st_population         35 non-null     float64
#  10  literacy_rate         35 non-null     float64
#  11  male_literacy_rate    35 non-null     float64
#  12  female_literacy_rate  35 non-null     float64
#  13  distcd                35 non-null     int64
#  14  blkcd                 35 non-null     int64
# ...

# %%
#checking for null values
df.isnull()
# Out:
#     ac_year  statcd  statname  area_sqkm  tot_population  urban_population  \
# 0     False   False     False      False           False             False
# 1     False   False     False      False           False             False
# 2     False   False     False      False           False             False
# 3     False   False     False      False           False             False
# 4     False   False     False      False           False             False
# 5     False   False     False      False           False             False
# 6     False   False     False      False           False             False
# 7     False   False     False      False           False             False
# 8     False   False     False      False           False             False
# 9     False   False     False      False           False             False
# 10    False   False     False      False           False             False
# ...

# %%
pd.set_option('display.max_rows',500)
pd.set_option('display.max_columns',500)
pd.set_option('display.width',1000)

# %%
df.shape
# Out:
# (35, 39)

# %%
df.tot_population.max()
# Out:
# 199581.48

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Area and population in the year 2015-16

# %%
plt.plot(df['ac_year'],df['area_sqkm'], label='area')
plt.plot(df['ac_year'],df['tot_population'], label='total population')
plt.plot(df['ac_year'],df['urban_population'], label='urban population')
plt.xlabel('year')
plt.ylabel('area')
plt.grid(True)
plt.legend()

# %% [markdown]
# # Area

# %%
df.area_sqkm.min()
# Out:
# 32

# %%
df.area_sqkm.max()
# Out:
# 342239

# %%
df.area_sqkm.mean()
# Out:
# 93921.14285714286

# %%
df.loc[:,["statname"]]
# Out:
#                           statname
# 0                Jammu And Kashmir
# 1                 Himachal Pradesh
# 2                           Punjab
# 3                       Chandigarh
# 4                      Uttarakhand
# 5                          Haryana
# 6   Delhi
# 7   Rajasthan
# 8                    Uttar Pradesh
# 9                            Bihar
# 10                          Sikkim
# 11               Arunachal Pradesh
# 12                        Nagaland
# 13                         Manipur
# 14  Mizoram
# 15                         Tripura
# 16  Meghalaya
# 17                           Assam
# 18  West Bengal
# 19                       Jharkhand
# 20                          Odisha
# 21                    Chhattisgarh
# 22                  MADHYA PRADESH
# 23                         Gujarat
# 24  Daman & Diu
# 25  Dadra & Nagar Haveli
# 26                     Maharashtra
# 27  Andhra Pradesh
# 28                       Karnataka
# 29  Goa
# 30  Lakshadweep
# ...

# %%
df.loc[[7, 9, 30],['statname','area_sqkm','literacy_rate']]
# Out:
#                           statname  area_sqkm  literacy_rate
# 7   Rajasthan                          342239          67.06
# 9                            Bihar      94163          63.82
# 30  Lakshadweep                            32          92.28

# %%
df.loc[[7, 9, 30],['statname','area_sqkm']].plot()
plt.show()

# %%
df.loc[[21, 30, 7, 5, 9],['statname','area_sqkm']]
# Out:
#                           statname  area_sqkm
# 21                    Chhattisgarh     135191
# 30  Lakshadweep                            32
# 7   Rajasthan                          342239
# 5                          Haryana      44212
# 9                            Bihar      94163

# %%
df.literacy_rate.min()
# Out:
# 63.82

# %%
df.literacy_rate.mean()
# Out:
# 78.64885714285714

# %%
df.loc[[7, 9, 30],['statname','area_sqkm','literacy_rate']]
# Out:
#                           statname  area_sqkm  literacy_rate
# 7   Rajasthan                          342239          67.06
# 9                            Bihar      94163          63.82
# 30  Lakshadweep                            32          92.28

# %%
df.area_sqkm.max()
# Out:
# 342239

# %%
df.area_sqkm.min()
# Out:
# 32

# %%
df.area_sqkm.mean()
# Out:
# 93921.14285714286

# %% [markdown]
# ## Bihar is a state with area almost equal to the avg area per sq km and least literacy rate
# ## Rajasthan is a state with high area and less than the avg literacy rate
# ## On the contrary Lakshwadeep has the least area with highest literacy rate

# %%
df.loc[[7, 9, 30],['literacy_rate','statname']].plot()
plt.show()

# %%
df.loc[[8],['statname','area_sqkm','literacy_rate']]
# Out:
#         statname  area_sqkm  literacy_rate
# 8  Uttar Pradesh     240928          69.72

# %% [markdown]
# # Uttar pradesh has highest population with moderate area and less than avg literacy rate

# %%
plt.plot(df['area_sqkm'],df['tot_population'])
plt.xlabel('Area')
plt.ylabel('Population')
plt.grid(True)
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df.head()
# Out:
#    ac_year  statcd           statname  area_sqkm  tot_population  urban_population  grwoth_rate  sexratio  sc_population  st_population  literacy_rate  male_literacy_rate  female_literacy_rate  distcd  blkcd  villages  clusters  schools  sch_1  sch_2  sch_3  sch_4  sch_5  sch_6  sch_7  sch_r_1  sch_r_2  sch_r_3  sch_r_4  sch_r_5  sch_r_6  sch_r_7  sch_u_1  sch_u_2  sch_u_3  sch_u_4  sch_u_5  sch_u_6  sch_u_7
# 0  2015-16       1  Jammu And Kashmir     222236        12548.93             20.05        23.71       883            7.4           11.9          68.74               78.26                 58.01      22    201      7263      1628     4202    486     95   2693    414     34    478      2      264       90     2012      376       30      346        0      222        5      681       38        4      132        2
# ...

# %%
df.max()
# Out:
# ac_year                                        2015-16
# statcd                                              35
# statname                West Bengal
# area_sqkm                                       342239
# tot_population                               199581.48
# urban_population                                 77.03
# grwoth_rate                                       55.5
# sexratio                                          1084
# sc_population                                     31.9
# st_population                                     94.8
# literacy_rate                                    93.91
# male_literacy_rate                               96.11
# female_literacy_rate                             91.98
# distcd                                              75
# blkcd                                              971
# villages                                         98470
# clusters                                         10594
# ...

# %%
df.min()
# Out:
# ac_year                                        2015-16
# statcd                                               1
# statname                Andaman & Nicobar Islands
# area_sqkm                                           32
# tot_population                                   64.43
# urban_population                                  8.36
# grwoth_rate                                      -0.47
# sexratio                                           618
# sc_population                                      0.0
# st_population                                      0.0
# literacy_rate                                    63.82
# male_literacy_rate                               73.39
# female_literacy_rate                             52.66
# distcd                                               1
# blkcd                                                1
# villages                                            10
# clusters                                             7
# ...

# %%
#ALL states
df[['literacy_rate']].plot()
plt.show()

# %% [markdown]
# ## States with lowest, moderate and highest literacy rates

# %%
df.loc[[31, 12, 32, 9],['statname','literacy_rate']]
# Out:
#       statname  literacy_rate
# 31      Kerala          93.91
# 12    Nagaland          80.11
# 32  Tamil Nadu          80.33
# 9        Bihar          63.82

# %% [markdown]
# ## Kerela has highest literacy rate
# ## Bihar has lowest literacy rate

# %%
df.loc[[31, 12, 32, 9],['statname','literacy_rate']].plot()
plt.show()

# %%
df.literacy_rate.max()
# Out:
# 93.91

# %% [markdown]
# ## Rajasthan has highest number of schools
# ## Lakshwadeep has the least number of schools
# ## Chattisgarh has less than the avg number of schools
# ## Haryana and bihar have more than the avg number of schools

# %%
df.schools.max()
# Out:
# 28195

# %%
df.schools.min()
# Out:
# 14

# %%
df.schools.mean()
# Out:
# 6819.457142857143

# %%
df.loc[:,["schools",'statname']]
# Out:
#     schools                        statname
# 0      4202               Jammu And Kashmir
# 1      3782                Himachal Pradesh
# 2      9171                          Punjab
# 3       160                      Chandigarh
# 4      3512                     Uttarakhand
# 5      7663                         Haryana
# 6      2061  Delhi
# 7     28195  Rajasthan
# 8     24569                   Uttar Pradesh
# 9      7627                           Bihar
# 10      227                          Sikkim
# 11      418               Arunachal Pradesh
# 12      736                        Nagaland
# 13     1109                         Manipur
# 14      753  Mizoram
# 15     1014                         Tripura
# 16     1555  Meghalaya
# 17     9062                           Assam
# 18    10194  West Bengal
# 19     4601                       Jharkhand
# 20    10745                          Odisha
# 21     6283                    Chhattisgarh
# 22    14893                  MADHYA PRADESH
# ...

# %%
df.loc[[21, 30, 7, 5, 9],['statname','schools']].plot()
plt.xlabel('State_id')
plt.ylabel('Schools')
plt.show()

# %%
df.head(3)
# Out:
#    ac_year  statcd           statname  area_sqkm  tot_population  urban_population  grwoth_rate  sexratio  sc_population  st_population  literacy_rate  male_literacy_rate  female_literacy_rate  distcd  blkcd  villages  clusters  schools  sch_1  sch_2  sch_3  sch_4  sch_5  sch_6  sch_7  sch_r_1  sch_r_2  sch_r_3  sch_r_4  sch_r_5  sch_r_6  sch_r_7  sch_u_1  sch_u_2  sch_u_3  sch_u_4  sch_u_5  sch_u_6  sch_u_7
# 0  2015-16       1  Jammu And Kashmir     222236        12548.93             20.05        23.71       883            7.4           11.9          68.74               78.26                 58.01      22    201      7263      1628     4202    486     95   2693    414     34    478      2      264       90     2012      376       30      346        0      222        5      681       38        4      132        2
# ...

# %% [markdown]
# ## Lakshwadeep has less than the avg growth rate
# ## Haryana has growth rate almost equal to the avg growth rate
# ## Bihar, Rajasthan and chattisgrah has more than the avg growth rate

# %%
df.grwoth_rate.max()
# Out:
# 55.5

# %%
df.grwoth_rate.min()
# Out:
# -0.47

# %%
df.grwoth_rate.mean()
# Out:
# 19.030857142857144

# %%
df.loc[[21, 30, 7, 5, 9],['statname','grwoth_rate']]
# Out:
#                           statname  grwoth_rate
# 21                    Chhattisgarh        22.59
# 30  Lakshadweep                            6.23
# 7   Rajasthan                             21.44
# 5                          Haryana        19.90
# 9                            Bihar        25.07

# %%
df.loc[[21, 30, 7, 5, 9],['statname','grwoth_rate']].plot()
#plt.xlabel('State_id')
#plt.ylabel('Schools')
plt.show()

# %% [markdown]
# ## Lakshwadeep has highest literacy rate
# ## Bihar has the least literacy rate
# ## Haryana has literacy rate almost equal to the avg literacy rate
# ## Chattisgarh and Rajasthan has literacy rate less than avg literacy rate

# %%
df.literacy_rate.max()
# Out:
# 93.91

# %%
df.literacy_rate.min()
# Out:
# 63.82

# %%
df.literacy_rate.mean()
# Out:
# 78.64885714285714

# %%
df.loc[[21, 30, 7, 5, 9],['statname','literacy_rate']]
# Out:
#                           statname  literacy_rate
# 21                    Chhattisgarh          71.04
# 30  Lakshadweep                             92.28
# 7   Rajasthan                               67.06
# 5                          Haryana          76.64
# 9                            Bihar          63.82

# %%
df.loc[[21, 30, 7, 5, 9],['statname','literacy_rate']].plot()
#plt.xlabel('State_id')
#plt.ylabel('Schools')
plt.show()

# %% [markdown]
# ## Deriving conclusions:

# %% [markdown]
# ### Rajasthan is a state with the highest area per square km, and has the highest number of schools with more than avg growth rate and less than avg literacy rate
# ### Bihar is a state with area per square km almost equal to the avg area per square km, and has more than the avg number of schools with more than avg growth rate and the least literacy rate
# ### Haryana has less than the avg area per square km and, has more than the avg number of schools with growth rate almost equal to avg growth rate and literacy rate almost equal to avg literacy rate
# ### Chattisgarh has more than the avg area per square km and has less than the avg number of schools with more than the avg growth rate and less than the avg literacy rate
# ### Lakshwadeep is a state with least area per sq km, and has the least number of schools with less than the avg growth rate and highest literacy rate

# %%
df.head(1)
# Out:
#    ac_year  statcd           statname  area_sqkm  tot_population  urban_population  grwoth_rate  sexratio  sc_population  st_population  literacy_rate  male_literacy_rate  female_literacy_rate  distcd  blkcd  villages  clusters  schools  sch_1  sch_2  sch_3  sch_4  sch_5  sch_6  sch_7  sch_r_1  sch_r_2  sch_r_3  sch_r_4  sch_r_5  sch_r_6  sch_r_7  sch_u_1  sch_u_2  sch_u_3  sch_u_4  sch_u_5  sch_u_6  sch_u_7
# 0  2015-16       1  Jammu And Kashmir     222236        12548.93             20.05        23.71       883            7.4           11.9          68.74               78.26                 58.01      22    201      7263      1628     4202    486     95   2693    414     34    478      2      264       90     2012      376       30      346        0      222        5      681       38        4      132        2

# %%
df.loc[[21, 30, 7, 5, 9],['statname','statcd']].plot()
df.loc[[21, 30, 7, 5, 9],['statname','area_sqkm']].plot()
df.loc[[21, 30, 7, 5, 9],['statname','tot_population']].plot()
df.loc[[21, 30, 7, 5, 9],['statname','urban_population']].plot()
df.loc[[21, 30, 7, 5, 9],['statname','grwoth_rate']].plot()
df.loc[[21, 30, 7, 5, 9],['statname','sexratio']].plot()
df.loc[[21, 30, 7, 5, 9],['statname','sc_population']].plot()
df.loc[[21, 30, 7, 5, 9],['statname','st_population']].plot()
df.loc[[21, 30, 7, 5, 9],['statname','literacy_rate']].plot()
df.loc[[21, 30, 7, 5, 9],['statname','male_literacy_rate']].plot()
df.loc[[21, 30, 7, 5, 9],['statname','female_literacy_rate']].plot()
df.loc[[21, 30, 7, 5, 9],['statname','distcd']].plot()
df.loc[[21, 30, 7, 5, 9],['statname','blkcd']].plot()
df.loc[[21, 30, 7, 5, 9],['statname','villages']].plot()
df.loc[[21, 30, 7, 5, 9],['statname','clusters']].plot()
df.loc[[21, 30, 7, 5, 9],['statname','schools']].plot()
# Out:
# <AxesSubplot: >

# %%
df.loc[:,["statname"]]
# Out:
#                           statname
# 0                Jammu And Kashmir
# 1                 Himachal Pradesh
# 2                           Punjab
# 3                       Chandigarh
# 4                      Uttarakhand
# 5                          Haryana
# 6   Delhi
# 7   Rajasthan
# 8                    Uttar Pradesh
# 9                            Bihar
# 10                          Sikkim
# 11               Arunachal Pradesh
# 12                        Nagaland
# 13                         Manipur
# 14  Mizoram
# 15                         Tripura
# 16  Meghalaya
# 17                           Assam
# 18  West Bengal
# 19                       Jharkhand
# 20                          Odisha
# 21                    Chhattisgarh
# 22                  MADHYA PRADESH
# 23                         Gujarat
# 24  Daman & Diu
# 25  Dadra & Nagar Haveli
# 26                     Maharashtra
# 27  Andhra Pradesh
# 28                       Karnataka
# 29  Goa
# 30  Lakshadweep
# ...

# %%
df.area_sqkm.plot()
df.tot_population.plot()
plt.legend()

#df.statname[0].loc[[31, 9],['statname','area_sqkm']].plot()

# %%
df.head(1)
# Out:
#    ac_year  statcd           statname  area_sqkm  tot_population  urban_population  grwoth_rate  sexratio  sc_population  st_population  literacy_rate  male_literacy_rate  female_literacy_rate  distcd  blkcd  villages  clusters  schools  sch_1  sch_2  sch_3  sch_4  sch_5  sch_6  sch_7  sch_r_1  sch_r_2  sch_r_3  sch_r_4  sch_r_5  sch_r_6  sch_r_7  sch_u_1  sch_u_2  sch_u_3  sch_u_4  sch_u_5  sch_u_6  sch_u_7
# 0  2015-16       1  Jammu And Kashmir     222236        12548.93             20.05        23.71       883            7.4           11.9          68.74               78.26                 58.01      22    201      7263      1628     4202    486     95   2693    414     34    478      2      264       90     2012      376       30      346        0      222        5      681       38        4      132        2

# %% [markdown]
# ## Kerela has the max sex ratio
# ## Daman and diu has the least sex ratio

# %%
df.sexratio.plot()
# Out:
# <AxesSubplot: >

# %%
df.statname
# Out:
# 0                  Jammu And Kashmir
# 1                   Himachal Pradesh
# 2                             Punjab
# 3                         Chandigarh
# 4                        Uttarakhand
# 5                            Haryana
# 6     Delhi
# 7     Rajasthan
# 8                      Uttar Pradesh
# 9                              Bihar
# 10                            Sikkim
# 11                 Arunachal Pradesh
# 12                          Nagaland
# 13                           Manipur
# 14    Mizoram
# 15                           Tripura
# 16    Meghalaya
# 17                             Assam
# 18    West Bengal
# 19                         Jharkhand
# 20                            Odisha
# 21                      Chhattisgarh
# 22                    MADHYA PRADESH
# 23                           Gujarat
# 24    Daman & Diu
# 25    Dadra & Nagar Haveli
# 26                       Maharashtra
# 27    Andhra Pradesh
# 28                         Karnataka
# 29    Goa
# ...

# %% [markdown]
# ## Punjab has the highest sc population

# %%
df.sc_population.min()
# Out:
# 0.0

# %%
df.sc_population.max()
# Out:
# 31.9

# %%
df.sc_population.mean()
# Out:
# 11.76

# %%
df.sc_population.plot()
# Out:
# <AxesSubplot: >

# %%
df.loc[[21, 30, 7, 5, 2, 9],['statname','literacy_rate']].plot()
#plt.xlabel('State_id')
#plt.ylabel('Schools')
plt.show()

# %%
df.sc_population
# Out:
# 0      7.4
# 1     25.2
# 2     31.9
# 3     18.9
# 4     18.8
# 5     20.2
# 6     16.8
# 7     17.8
# 8     20.7
# 9     15.9
# 10     4.6
# 11     0.0
# 12     0.0
# 13     3.8
# 14     0.1
# 15    17.8
# 16     0.6
# 17     7.2
# 18    23.5
# 19    12.1
# 20    17.1
# 21    12.8
# 22    15.6
# 23     6.7
# 24     2.5
# 25     1.8
# 26    11.8
# 27    16.4
# 28    17.1
# 29     1.7
# 30     0.0
# 31     9.1
# 32    20.0
# 33    15.7
# 34     0.0
# Name: sc_population, dtype: float64

# %%
df.sc_population
df.statname
# Out:
# 0                  Jammu And Kashmir
# 1                   Himachal Pradesh
# 2                             Punjab
# 3                         Chandigarh
# 4                        Uttarakhand
# 5                            Haryana
# 6     Delhi
# 7     Rajasthan
# 8                      Uttar Pradesh
# 9                              Bihar
# 10                            Sikkim
# 11                 Arunachal Pradesh
# 12                          Nagaland
# 13                           Manipur
# 14    Mizoram
# 15                           Tripura
# 16    Meghalaya
# 17                             Assam
# 18    West Bengal
# 19                         Jharkhand
# 20                            Odisha
# 21                      Chhattisgarh
# 22                    MADHYA PRADESH
# 23                           Gujarat
# 24    Daman & Diu
# 25    Dadra & Nagar Haveli
# 26                       Maharashtra
# 27    Andhra Pradesh
# 28                         Karnataka
# 29    Goa
# ...

# %%
df.statcd
df.statname
# Out:
# 0                  Jammu And Kashmir
# 1                   Himachal Pradesh
# 2                             Punjab
# 3                         Chandigarh
# 4                        Uttarakhand
# 5                            Haryana
# 6     Delhi
# 7     Rajasthan
# 8                      Uttar Pradesh
# 9                              Bihar
# 10                            Sikkim
# 11                 Arunachal Pradesh
# 12                          Nagaland
# 13                           Manipur
# 14    Mizoram
# 15                           Tripura
# 16    Meghalaya
# 17                             Assam
# 18    West Bengal
# 19                         Jharkhand
# 20                            Odisha
# 21                      Chhattisgarh
# 22                    MADHYA PRADESH
# 23                           Gujarat
# 24    Daman & Diu
# 25    Dadra & Nagar Haveli
# 26                       Maharashtra
# 27    Andhra Pradesh
# 28                         Karnataka
# 29    Goa
# ...

# %%
df.sexratio
# Out:
# 0      883
# 1      974
# 2      893
# 3      818
# 4      963
# 5      877
# 6      866
# 7      926
# 8      908
# 9      916
# 10     889
# 11     920
# 12     931
# 13     987
# 14     975
# 15     961
# 16     986
# 17     954
# 18     947
# 19     947
# 20     978
# 21     991
# 22     930
# 23     918
# 24     618
# 25     775
# 26     925
# 27     992
# 28     968
# 29     968
# 30     946
# 31    1084
# 32     995
# 33    1038
# 34     878
# Name: sexratio, dtype: int64

# %%
df.sexratio.min()
# Out:
# 618

# %%
df.sexratio.mean()
# Out:
# 929.2857142857143

# %%
df.sexratio.max()
# Out:
# 1084

# %%
df.ac_year[0]
# Out:
# '2015-16'

# %% [markdown]
# ## Additional comparisions

# %%
plt.plot(df['urban_population'],label='Urban')
plt.plot(df['tot_population'],label='Total')
plt.xlabel('No.of states')
plt.ylabel('Population')
plt.grid(True)
plt.legend()

# %%
plt.plot(df['grwoth_rate'],df['tot_population'])

# %%
plt.plot(df['urban_population'],df['area_sqkm'],label='Urban Population')
plt.plot(df['grwoth_rate'],df['area_sqkm'],label='Growth rate')
plt.plot(df['sexratio'],df['area_sqkm'],label='Sexratio')
plt.plot(df['sc_population'],df['area_sqkm'],label='sc_population')
plt.plot(df['st_population'],df['area_sqkm'],label='st_population')
plt.plot(df['tot_population'],df['area_sqkm'],label='tot_population')
plt.plot(df['literacy_rate'],df['area_sqkm'],label='literacy_rate')
plt.plot(df['female_literacy_rate'],df['area_sqkm'],label='female_literacy_rate')
plt.plot(df['distcd'],df['area_sqkm'],label='distcd')
plt.plot(df['blkcd'],df['area_sqkm'],label='blkcd')
plt.plot(df['villages'],df['area_sqkm'],label='villages')
plt.plot(df['clusters'],df['area_sqkm'],label='clusters')
plt.plot(df['schools'],df['area_sqkm'],label='schools')
plt.xlabel('Population')
plt.ylabel('Area in sq.km')
plt.grid(True)
plt.legend()

# %%
plt.plot(df['urban_population'],df['grwoth_rate'],label='Urban Population')
plt.plot(df['grwoth_rate'],df['grwoth_rate'],label='Growth rate')
plt.plot(df['sexratio'],df['grwoth_rate'],label='Sexratio')
plt.plot(df['sc_population'],df['grwoth_rate'],label='sc_population')
plt.plot(df['st_population'],df['grwoth_rate'],label='st_population')
plt.plot(df['tot_population'],df['grwoth_rate'],label='tot_population')
plt.plot(df['literacy_rate'],df['grwoth_rate'],label='literacy_rate')
plt.plot(df['female_literacy_rate'],df['grwoth_rate'],label='female_literacy_rate')
plt.plot(df['distcd'],df['grwoth_rate'],label='distcd')
plt.plot(df['blkcd'],df['grwoth_rate'],label='blkcd')
plt.plot(df['villages'],df['grwoth_rate'],label='villages')
plt.plot(df['clusters'],df['grwoth_rate'],label='clusters')
plt.plot(df['schools'],df['grwoth_rate'],label='schools')
plt.xlabel('Population')
plt.ylabel('grwoth_rate')
plt.grid(True)
plt.legend()

# %%
plt.plot(df['urban_population'],df['sexratio'],label='Urban Population')
plt.plot(df['grwoth_rate'],df['sexratio'],label='Growth rate')
plt.plot(df['sexratio'],df['sexratio'],label='Sexratio')
plt.plot(df['sc_population'],df['sexratio'],label='sc_population')
plt.plot(df['st_population'],df['sexratio'],label='st_population')
plt.plot(df['tot_population'],df['sexratio'],label='tot_population')
plt.plot(df['literacy_rate'],df['sexratio'],label='literacy_rate')
plt.plot(df['female_literacy_rate'],df['sexratio'],label='female_literacy_rate')
plt.plot(df['distcd'],df['sexratio'],label='distcd')
plt.plot(df['blkcd'],df['sexratio'],label='blkcd')
plt.plot(df['villages'],df['sexratio'],label='villages')
plt.plot(df['clusters'],df['sexratio'],label='clusters')
plt.plot(df['schools'],df['sexratio'],label='schools')
plt.xlabel('Population')
plt.ylabel('Sex Ratio')
plt.grid(True)
plt.legend()

# %%
plt.plot(df['urban_population'],df['sc_population'],label='Urban Population')
plt.plot(df['grwoth_rate'],df['sc_population'],label='Growth rate')
plt.plot(df['sexratio'],df['sc_population'],label='Sexratio')
plt.plot(df['sc_population'],df['sc_population'],label='sc_population')
plt.plot(df['st_population'],df['sc_population'],label='st_population')
plt.plot(df['tot_population'],df['sc_population'],label='tot_population')
plt.plot(df['literacy_rate'],df['sc_population'],label='literacy_rate')
plt.plot(df['female_literacy_rate'],df['sc_population'],label='female_literacy_rate')
plt.plot(df['distcd'],df['sc_population'],label='distcd')
plt.plot(df['blkcd'],df['sc_population'],label='blkcd')
plt.plot(df['villages'],df['sc_population'],label='villages')
plt.plot(df['clusters'],df['sc_population'],label='clusters')
plt.plot(df['schools'],df['sc_population'],label='schools')
plt.xlabel('Population')
plt.ylabel('sc_population')
plt.grid(True)
plt.legend()

# %%
plt.plot(df['urban_population'],df['st_population'],label='Urban Population')
plt.plot(df['grwoth_rate'],df['st_population'],label='Growth rate')
plt.plot(df['sexratio'],df['st_population'],label='Sexratio')
plt.plot(df['sc_population'],df['st_population'],label='sc_population')
plt.plot(df['st_population'],df['st_population'],label='st_population')
plt.plot(df['tot_population'],df['st_population'],label='tot_population')
plt.plot(df['literacy_rate'],df['st_population'],label='literacy_rate')
plt.plot(df['female_literacy_rate'],df['st_population'],label='female_literacy_rate')
plt.plot(df['distcd'],df['st_population'],label='distcd')
plt.plot(df['blkcd'],df['st_population'],label='blkcd')
plt.plot(df['villages'],df['st_population'],label='villages')
plt.plot(df['clusters'],df['st_population'],label='clusters')
plt.plot(df['schools'],df['st_population'],label='schools')
plt.xlabel('Population')
plt.ylabel('st_population')
plt.grid(True)
plt.legend()

# %%
plt.plot(df['urban_population'],df['villages'],label='Urban Population')
plt.plot(df['grwoth_rate'],df['villages'],label='Growth rate')
plt.plot(df['sexratio'],df['villages'],label='Sexratio')
plt.plot(df['sc_population'],df['villages'],label='sc_population')
plt.plot(df['st_population'],df['villages'],label='st_population')
plt.plot(df['tot_population'],df['villages'],label='tot_population')
plt.plot(df['literacy_rate'],df['villages'],label='literacy_rate')
plt.plot(df['female_literacy_rate'],df['villages'],label='female_literacy_rate')
plt.plot(df['distcd'],df['villages'],label='distcd')
plt.plot(df['blkcd'],df['villages'],label='blkcd')
plt.plot(df['villages'],df['villages'],label='villages')
plt.plot(df['clusters'],df['villages'],label='clusters')
plt.plot(df['schools'],df['villages'],label='schools')
plt.xlabel('Population')
plt.ylabel('Villages')
plt.grid(True)
plt.legend()

# %%
plt.plot(df['urban_population'],df['schools'],label='Urban Population')
plt.plot(df['grwoth_rate'],df['schools'],label='Growth rate')
plt.plot(df['sexratio'],df['schools'],label='Sexratio')
plt.plot(df['sc_population'],df['schools'],label='sc_population')
plt.plot(df['st_population'],df['schools'],label='st_population')
plt.plot(df['tot_population'],df['schools'],label='tot_population')
plt.plot(df['literacy_rate'],df['schools'],label='literacy_rate')
plt.plot(df['female_literacy_rate'],df['schools'],label='female_literacy_rate')
plt.plot(df['distcd'],df['schools'],label='distcd')
plt.plot(df['blkcd'],df['schools'],label='blkcd')
plt.plot(df['villages'],df['schools'],label='villages')
plt.plot(df['clusters'],df['schools'],label='clusters')
plt.plot(df['schools'],df['schools'],label='schools')
plt.xlabel('Population')
plt.ylabel('st_population')
plt.grid(True)
plt.legend()

# %%
import seaborn as sns
sns.set()
sns.scatterplot(df['urban_population'])
sns.scatterplot(df['literacy_rate'])
# Out:
# <AxesSubplot: ylabel='urban_population'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 39 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ac_year               35 non-null     object
#  1   statcd                35 non-null     int64
#  2   statname              35 non-null     object
#  3   area_sqkm             35 non-null     int64
#  4   tot_population        35 non-null     float64
#  5   urban_population      35 non-null     float64
#  6   grwoth_rate           35 non-null     float64
#  7   sexratio              35 non-null     int64
#  8   sc_population         35 non-null     float64
#  9   st_population         35 non-null     float64
#  10  literacy_rate         35 non-null     float64
#  11  male_literacy_rate    35 non-null     float64
#  12  female_literacy_rate  35 non-null     float64
#  13  distcd                35 non-null     int64
#  14  blkcd                 35 non-null     int64
# ...

# %% [markdown]
# ## subplot

# %%
import matplotlib.pyplot as plt
fig,axes= plt.subplots(2,2)
axes[0,0].hist(df['area_sqkm'])
axes[0,1].plot(df['statcd'],df['tot_population'])
axes[1,0].plot(df['statcd'],df['grwoth_rate'])
axes[1,1].plot(df['statcd'],df['literacy_rate'])

# %%
df.hist()
# Out:
# array([[<AxesSubplot: title={'center': 'statcd'}>,
#         <AxesSubplot: title={'center': 'area_sqkm'}>,
#         <AxesSubplot: title={'center': 'tot_population'}>,
#         <AxesSubplot: title={'center': 'urban_population'}>,
#         <AxesSubplot: title={'center': 'grwoth_rate'}>,
#         <AxesSubplot: title={'center': 'sexratio'}>],
#        [<AxesSubplot: title={'center': 'sc_population'}>,
#         <AxesSubplot: title={'center': 'st_population'}>,
#         <AxesSubplot: title={'center': 'literacy_rate'}>,
#         <AxesSubplot: title={'center': 'male_literacy_rate'}>,
#         <AxesSubplot: title={'center': 'female_literacy_rate'}>,
#         <AxesSubplot: title={'center': 'distcd'}>],
#        [<AxesSubplot: title={'center': 'blkcd'}>,
#         <AxesSubplot: title={'center': 'villages'}>,
#         <AxesSubplot: title={'center': 'clusters'}>,
#         <AxesSubplot: title={'center': 'schools'}>,
#         <AxesSubplot: title={'center': 'sch_1'}>,
# ...

# %%
df.grwoth_rate.min()
# Out:
# -0.47

# %%
import seaborn as sns
sns.heatmap(df.corr(), annot=False,fmt='.2f')
# Out:
# C:\Users\Anusha\AppData\Local\Temp\ipykernel_6852\3116627686.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=False,fmt='.2f')
# <AxesSubplot: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 39 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ac_year               35 non-null     object
#  1   statcd                35 non-null     int64
#  2   statname              35 non-null     object
#  3   area_sqkm             35 non-null     int64
#  4   tot_population        35 non-null     float64
#  5   urban_population      35 non-null     float64
#  6   grwoth_rate           35 non-null     float64
#  7   sexratio              35 non-null     int64
#  8   sc_population         35 non-null     float64
#  9   st_population         35 non-null     float64
#  10  literacy_rate         35 non-null     float64
#  11  male_literacy_rate    35 non-null     float64
#  12  female_literacy_rate  35 non-null     float64
#  13  distcd                35 non-null     int64
#  14  blkcd                 35 non-null     int64
# ...

# %%
import seaborn as sns
sns.jointplot(x='sc_population',y='literacy_rate',data =df)

# %%
df.sc_population.min()
# Out:
# 0.0

# %%
df.sc_population.max()
# Out:
# 31.9

# %%
df.sc_population.mean()
# Out:
# 11.76

# %%
df.statname
# Out:
# 0                  Jammu And Kashmir
# 1                   Himachal Pradesh
# 2                             Punjab
# 3                         Chandigarh
# 4                        Uttarakhand
# 5                            Haryana
# 6     Delhi
# 7     Rajasthan
# 8                      Uttar Pradesh
# 9                              Bihar
# 10                            Sikkim
# 11                 Arunachal Pradesh
# 12                          Nagaland
# 13                           Manipur
# 14    Mizoram
# 15                           Tripura
# 16    Meghalaya
# 17                             Assam
# 18    West Bengal
# 19                         Jharkhand
# 20                            Odisha
# 21                      Chhattisgarh
# 22                    MADHYA PRADESH
# 23                           Gujarat
# 24    Daman & Diu
# 25    Dadra & Nagar Haveli
# 26                       Maharashtra
# 27    Andhra Pradesh
# 28                         Karnataka
# 29    Goa
# ...

# %%
df.literacy_rate
# Out:
# 0     68.74
# 1     83.78
# 2     76.68
# 3     86.43
# 4     79.63
# 5     76.64
# 6     86.34
# 7     67.06
# 8     69.72
# 9     63.82
# 10    82.20
# 11    66.95
# 12    80.11
# 13    79.85
# 14    91.58
# 15    87.75
# 16    75.48
# 17    73.18
# 18    77.08
# 19    67.63
# 20    73.45
# 21    71.04
# 22    70.63
# 23    79.31
# 24    87.07
# 25    77.65
# 26    82.91
# 27    67.66
# 28    75.60
# 29    87.40
# 30    92.28
# 31    93.91
# 32    80.33
# 33    86.55
# 34    86.27
# Name: literacy_rate, dtype: float64

# %%
df.literacy_rate.min()
# Out:
# 63.82

# %%
df.sc_population
#highest =32.9 -->2 is punjab
# Out:
# 0      7.4
# 1     25.2
# 2     31.9
# 3     18.9
# 4     18.8
# 5     20.2
# 6     16.8
# 7     17.8
# 8     20.7
# 9     15.9
# 10     4.6
# 11     0.0
# 12     0.0
# 13     3.8
# 14     0.1
# 15    17.8
# 16     0.6
# 17     7.2
# 18    23.5
# 19    12.1
# 20    17.1
# 21    12.8
# 22    15.6
# 23     6.7
# 24     2.5
# 25     1.8
# 26    11.8
# 27    16.4
# 28    17.1
# 29     1.7
# 30     0.0
# 31     9.1
# 32    20.0
# 33    15.7
# 34     0.0
# Name: sc_population, dtype: float64

# %%
sns.catplot(x='sc_population',y='literacy_rate',kind='violin',data=df)

# %%
sns.catplot(x='st_population',y='literacy_rate',kind='violin',data=df) #kind is the shape

# %%
sns.scatterplot(df['literacy_rate'])
# Out:
# <AxesSubplot: ylabel='literacy_rate'>

# %% [markdown]
# ## Overall comparision

# %%
plt.plot(df['urban_population'],df['statname'],label='Urban Population')
plt.plot(df['grwoth_rate'],df['statname'],label='Growth rate')
plt.plot(df['sexratio'],df['statname'],label='Sexratio')
plt.plot(df['sc_population'],df['statname'],label='sc_population')
plt.plot(df['st_population'],df['statname'],label='st_population')
plt.plot(df['tot_population'],df['statname'],label='tot_population')
plt.plot(df['area_sqkm'],df['statname'],label='area_sqkm')
plt.plot(df['literacy_rate'],df['statname'],label='literacy_rate')
plt.plot(df['female_literacy_rate'],df['statname'],label='female_literacy_rate')
plt.plot(df['distcd'],df['statname'],label='distcd')
plt.plot(df['blkcd'],df['statname'],label='blkcd')
plt.plot(df['villages'],df['statname'],label='villages')
plt.plot(df['clusters'],df['statname'],label='clusters')
plt.plot(df['schools'],df['statname'],label='schools')
plt.plot(df['sch_1'],df['statname'],label='sch_1')
plt.plot(df['sch_2'],df['statname'],label='sch_2')
plt.plot(df['sch_3'],df['statname'],label='sch_3')
plt.plot(df['sch_4'],df['statname'],label='sch_4')
plt.plot(df['sch_5'],df['statname'],label='sch_5')
plt.plot(df['sch_6'],df['statname'],label='sch_6')
plt.plot(df['sch_7'],df['statname'],label='sch_7')
plt.plot(df['sch_r_1'],df['statname'],label='sch_r_1')
plt.plot(df['sch_r_2'],df['statname'],label='sch_r_2')
plt.plot(df['sch_r_3'],df['statname'],label='sch_r_3')
plt.plot(df['sch_r_4'],df['statname'],label='sch_r_4')
plt.plot(df['sch_r_5'],df['statname'],label='sch_r_5')
plt.plot(df['sch_r_6'],df['statname'],label='sch_r_6')
plt.xlabel('Population')
plt.ylabel('States')
plt.grid(True)
plt.legend()
